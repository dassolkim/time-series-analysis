# %%
from fastdtw import fastdtw
from scipy.spatial.distance import euclidean
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %%
fs = 20
t = np.arange(0, 3, 1 / fs)
f = 30
arraysA = np.sin(4*t) 
arraysB = -np.sin(4*t)
print(arraysA, arraysB)
# Out:
# [ 0.          0.19866933  0.38941834  0.56464247  0.71735609  0.84147098
#   0.93203909  0.98544973  0.9995736   0.97384763  0.90929743  0.8084964
#   0.67546318  0.51550137  0.33498815  0.14112001 -0.05837414 -0.2555411
#  -0.44252044 -0.61185789 -0.7568025  -0.87157577 -0.95160207 -0.993691
#  -0.99616461 -0.95892427 -0.88345466 -0.77276449 -0.63126664 -0.46460218
#  -0.2794155  -0.0830894   0.1165492   0.31154136  0.49411335  0.6569866
#   0.79366786  0.8987081   0.96791967  0.99854335  0.98935825  0.94073056
#   0.85459891  0.7343971   0.58491719  0.41211849  0.22288991  0.02477543
#  -0.17432678 -0.36647913 -0.54402111 -0.69987469 -0.82782647 -0.92277542
#  -0.98093623 -0.99999021 -0.97917773 -0.91932853 -0.82282859 -0.69352508] [-0.         -0.19866933 -0.38941834 -0.56464247 -0.71735609 -0.84147098
#  -0.93203909 -0.98544973 -0.9995736  -0.97384763 -0.90929743 -0.8084964
#  -0.67546318 -0.51550137 -0.33498815 -0.14112001  0.05837414  0.2555411
# ...

# %%
distance_eu = euclidean(arraysA, arraysB)
distance_dtw, path = fastdtw(arraysA, arraysB, dist=euclidean)

# %%
plt.figure(figsize=(16,5),dpi=100)
plt.plot(range(len(arraysA)),arraysA, color='red')
plt.plot(range(len(arraysB)),arraysB, color='blue')
plt.xlabel("x")
plt.ylabel("y")
plt.title("DTW distance same scale | dtw distance: {} vs Eucliean distance: {}".format(round(distance_dtw, 3), round(distance_eu, 3)), fontsize=15)
plt.legend(['sin(4*t)','-sint(4*t)'])
plt.show()
print("Corrcoef")
np.corrcoef(arraysA, arraysB)
# Out:
# Corrcoef
# array([[ 1., -1.],
#        [-1.,  1.]])

# %%
interp_ind = np.arange(0, len(dtA),len(dtA)/float(len(dtB)))
dtB = np.interp(np.arange(0,len(dtA),1),interp_ind,dtB)


# print(interp_dtB.shape)

dtA = np.arange(1,10)
dtB = np.arange(5,14)
print(dtA)
print(dtB)
distance_E = euclidean(dtA, dtB)
distance_D, path = fastdtw(dtA, dtB, dist=euclidean)

plt.figure(figsize=(16,5),dpi=100)
plt.plot(range(len(dtA)),dtA, color='red')
plt.plot(range(len(dtB)),dtB, color='blue')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear data | Eucliean distance: {}".format(round(distance_E, 3), fontsize=15))
plt.legend(['dtA','dtB'])
plt.show()
print("Corrcoef")
np.corrcoef(dtA, dtB)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [ 5  6  7  8  9 10 11 12 13]
# Corrcoef
# array([[1., 1.],
#        [1., 1.]])
