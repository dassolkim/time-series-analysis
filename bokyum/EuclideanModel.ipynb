# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd

read_data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/data/time_series-3000.csv')

# %%
read_data.head(2)
# Out:
#    Unnamed: 0         V1         V2  ...        V58        V59        V60
# 0           0  30.336372  31.171370  ...  35.357129  25.639609  35.755350
# 1           1  31.794035  28.512789  ...  26.394683  27.291384  33.927718
#
# [2 rows x 61 columns]

# %%
read_data.loc[0, : ]
# Out:
# Unnamed: 0     0.000000
# V1            30.336372
# V2            31.171370
# V3            30.280258
# V4            30.249316
#                 ...
# V56           25.827475
# V57           32.936161
# V58           35.357129
# V59           25.639609
# V60           35.755350
# Name: 0, Length: 61, dtype: float64

# %%
import matplotlib.pyplot as plt

x = read_data.loc[0, : ]
y = read_data.loc[1, : ]

# %%
x.head()
# Out:
# Unnamed: 0     0.000000
# V1            30.336372
# V2            31.171370
# V3            30.280258
# V4            30.249316
# Name: 0, dtype: float64

# %%
plt.plot(x) # x
plt.plot(y)
plt.show()

# %%
import numpy as np

np_x = x.to_numpy()
np_y = y.to_numpy()

temp = np_x - np_y
temp * temp
# Out:
# array([1.00000000e+00, 2.12478181e+00, 7.06805329e+00, 9.07467851e+00,
#        5.72615529e-01, 1.97142449e-03, 2.96486675e+01, 9.35969691e-02,
#        5.49068860e+01, 6.73563965e+01, 1.48948178e+01, 3.63077436e+01,
#        2.00131724e+01, 9.01260344e+01, 6.35856614e+01, 5.93714798e-01,
#        8.13881116e+01, 1.98456380e+00, 2.83055951e-01, 5.36575508e-01,
#        3.51881793e+00, 9.66403065e-01, 1.33657259e-01, 2.59936145e+00,
#        4.45560254e+01, 1.51431111e+01, 1.65236040e+01, 2.45063426e+01,
#        3.76228172e+01, 6.14007017e+00, 5.25767134e-01, 1.13642174e-01,
#        1.42769015e+01, 2.24087533e-01, 1.21843127e+00, 5.96903590e-01,
#        1.10500762e+02, 4.28286675e+01, 3.77416548e+00, 3.93714994e+00,
#        1.52603389e+01, 1.47959731e+01, 1.73007867e+01, 2.11448586e+00,
#        7.20551994e+01, 1.16380223e+02, 6.39386542e+00, 1.33776878e+02,
#        4.64981488e+00, 2.18169094e+01, 3.94075336e+01, 2.76306362e+01,
#        8.65489688e+00, 1.89765429e+00, 2.30542490e+01, 7.92639694e+01,
#        5.02527369e+00, 1.61057734e-01, 8.03254442e+01, 2.72835961e+00,
#        3.34024021e+00])

# %%
def euclidean(x, y):
  temp = x - y
  temp = temp * temp
  return np.sqrt(temp)

# %%
euclidean(np_x, np_y)
# Out:
# array([ 1.        ,  1.45766313,  2.65858107,  3.01242071,  0.75671364,
#         0.04440073,  5.445059  ,  0.30593622,  7.40991809,  8.20709428,
#         3.85938049,  6.02559072,  4.47360843,  9.49347325,  7.97406179,
#         0.77052891,  9.02153599,  1.40874547,  0.53203003,  0.73251315,
#         1.87585126,  0.98305802,  0.36559166,  1.61225353,  6.67502999,
#         3.89141505,  4.06492361,  4.95038812,  6.13374415,  2.4779165 ,
#         0.72509802,  0.33710855,  3.77847873,  0.47337885,  1.10382574,
#         0.77259536, 10.51193425,  6.54436151,  1.94272115,  1.98422528,
#         3.90644838,  3.8465534 ,  4.15942143,  1.45412718,  8.48853341,
#        10.78796659,  2.52860938, 11.56619547,  2.15634294,  4.67085746,
#         6.277542  ,  5.25648516,  2.94192061,  1.37755374,  4.80148404,
#         8.90303147,  2.24171222,  0.40131999,  8.96244633,  1.65177468,
#         1.82763241])

# %%
plt.plot(euclidean(np_x, np_y))
plt.show()

# %%
read_data = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/data/time_series-3000.csv')

# %%
x = read_data.loc[:449, :]
x
# Out:
#      Unnamed: 0         V1         V2  ...        V58        V59        V60
# 0             0  30.336372  31.171370  ...  35.357129  25.639609  35.755350
# 1             1  31.794035  28.512789  ...  26.394683  27.291384  33.927718
# 2             2  34.833471  25.560185  ...  25.348651  32.171546  27.202015
# 3             3  31.099652  34.075072  ...  34.362526  32.401752  24.147639
# 4             4  34.250256  26.464770  ...  32.154170  26.663376  29.093435
# ..          ...        ...        ...  ...        ...        ...        ...
# 445         445  30.691089  29.550580  ...  34.805862  29.123095  29.745106
# 446         446  25.860893  26.904049  ...  24.725854  28.854384  32.271839
# 447         447  27.617403  32.080559  ...  30.390559  31.389254  24.063030
# 448         448  25.594287  34.215148  ...  35.723890  35.856717  33.804220
# 449         449  25.231492  25.350182  ...  28.281667  35.152895  32.493528
#
# [450 rows x 61 columns]

# %%
y = read_data.loc[451, :]
y
# Out:
# Unnamed: 0    451.000000
# V1             26.714049
# V2             33.391643
# V3             29.761365
# V4             24.745688
#                  ...
# V56            35.488666
# V57            29.166672
# V58            32.753184
# V59            35.111554
# V60            32.250607
# Name: 451, Length: 61, dtype: float64

# %%
np_x_list = x.to_numpy()
print(np_x_list.shape)
print(np_x_list[0, :])
# Out:
# (450, 61)
# [ 0.         30.3363719  31.17136968 30.2802581  30.24931642 29.27374708
#  32.35022277 34.83026701 33.6123572  27.30503703 30.22715147 32.84063808
#  27.1760655  24.8020174  34.80856178 34.61003358 34.40660539 28.84233918
#  32.9590406  34.07222743 32.02907561 28.40786122 33.24100352 34.04921724
#  35.12512528 35.25214258 33.87880843 28.84579524 33.53277975 25.13543563
#  33.30411938 29.59379607 27.97848426 34.22031243 27.05248063 29.69394341
#  24.78737706 31.34802906 26.49418504 29.45138586 25.46821159 32.97235218
#  27.30830036 29.96012882 24.58120974 24.3382789  33.34491673 35.80719565
#  29.37937185 31.18512351 25.90498842 25.23888702 33.02266821 32.66969965
#  33.69872921 35.04374334 25.82747492 32.93616054 35.35712947 25.63960946
#  35.75535033]

# %%
np_y = y.to_numpy()
print(np_y.shape)
print(np_y)
# Out:
# (61,)
# [451.          26.71404871  33.39164323  29.76136528  24.74568793
#   28.12990444  26.92680632  24.2864671   31.71458661  24.62571645
#   30.40323453  33.57858478  25.76872071  29.86446775  35.76935674
#   26.46177422  26.02238074  25.60173532  28.21781393  32.97552971
#   26.55218013  28.12624543  30.50518497  24.48525049  34.43768506
#   30.39307139  31.26847256  24.14042604  28.20622595  26.27030662
#   31.23553186  28.95804852  26.45759125  28.89029005  34.99881344
#   31.661979    35.46750469  26.61918986  33.67419976  27.30541979
#   30.91493806  35.93207184  26.65518482  32.00013592  27.54887195
#   33.0206129   24.56099468  29.57809999  25.15378704  25.46387349
#   24.65263144  25.66710956  32.0368745   31.493476    26.75592071
#   29.39935253  35.48866566  29.16667193  32.75318434  35.11155388
#   32.25060668]

# %%
np_x_list.shape[0]
np_x_list[0, :] - np_y
# Out:
# array([-4.51000000e+02,  3.62232319e+00, -2.22027355e+00,  5.18892814e-01,
#         5.50362849e+00,  1.14384264e+00,  5.42341645e+00,  1.05437999e+01,
#         1.89777060e+00,  2.67932058e+00, -1.76083066e-01, -7.37946700e-01,
#         1.40734479e+00, -5.06245035e+00, -9.60794960e-01,  8.14825936e+00,
#         8.38422465e+00,  3.24060386e+00,  4.74122667e+00,  1.09669772e+00,
#         5.47689548e+00,  2.81615792e-01,  2.73581855e+00,  9.56396674e+00,
#         6.87440215e-01,  4.85907119e+00,  2.61033587e+00,  4.70536920e+00,
#         5.32655380e+00, -1.13487099e+00,  2.06858752e+00,  6.35747549e-01,
#         1.52089301e+00,  5.33002237e+00, -7.94633281e+00, -1.96803559e+00,
#        -1.06801276e+01,  4.72883920e+00, -7.18001473e+00,  2.14596606e+00,
#        -5.44672647e+00, -2.95971966e+00,  6.53115541e-01, -2.04000710e+00,
#        -2.96766222e+00, -8.68233399e+00,  8.78392205e+00,  6.22909565e+00,
#         4.22558481e+00,  5.72125002e+00,  1.25235698e+00, -4.28222540e-01,
#         9.85793713e-01,  1.17622365e+00,  6.94280850e+00,  5.64439081e+00,
#        -9.66119074e+00,  3.76948861e+00,  2.60394513e+00, -9.47194442e+00,
#         3.50474365e+00])

# %%
def euclidean(x, y):
  minimal_value = x[0 , 1:] - y[1:]
  minimal_value = minimal_value * minimal_value * minimal_value * minimal_value
  minimal_value = np.sqrt(minimal_value)
  minimal_value_sum = minimal_value.sum() 
  index = -1
  i = 0

  for temp in x:
    
    temp = temp[1:] - y[1:]
    temp = temp * temp
    temp = np.sqrt(temp)
    temp_value_sum = temp.sum()
    
    if (temp_value_sum < minimal_value_sum):
      minimal_value_sum = temp_value_sum
      index = i
    i += 1
    

  print('가장 비슷한 행은 = ', index)
  print('가장 작은 Euclidean Distance 값은 : ', minimal_value_sum)

  return index

# %%
minimal_index = euclidean(np_x_list, np_y)
# Out:
# 가장 비슷한 행은 =  98
# 가장 작은 Euclidean Distance 값은 :  182.51923510849207

# %%
plt.plot(np_x_list[minimal_index, 1:])
plt.plot(np_y[1:])
plt.show()

# %%
def euclidean(x, y):
  maxl_value_sum = 0
  index = -1
  i = 0

  for temp in x:
    
    temp = temp[1:] - y[1:]
    temp = temp * temp
    temp = np.sqrt(temp)
    temp_value_sum = temp.sum()
    
    if (temp_value_sum > maxl_value_sum):
      maxl_value_sum = temp_value_sum
      index = i
    i += 1
    

  print('가장 다른 행은 = ', index)
  print('가장 큰 Euclidean Distance 값은 : ', maxl_value_sum)

  return index

# %%
max_index = euclidean(np_x_list, np_y)
# Out:
# 가장 다른 행은 =  353
# 가장 큰 Euclidean Distance 값은 :  296.31908158424636

# %%
plt.plot(np_x_list[max_index, 1:])
plt.plot(np_y[1:])
plt.show()
