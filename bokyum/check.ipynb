# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Fridge = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/Fridge.txt', delimiter='\t')
LSF5_10= pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/LSF5_10.txt', delimiter = '\t')
LSF6_10 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/LSF6_10.txt', delimiter = '\t')
RW1 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/RW1.txt', delimiter = '\t')
RW2 = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/RW2.txt', delimiter = '\t')
currency10a = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/currency10a.txt', delimiter = '\t')
currency10b = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/currency10b.txt', delimiter = '\t')
lightCurveA = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/lightCurveA.txt', delimiter = '\t')
lightCurveB = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/lightCurveB.txt', delimiter = '\t')
ratbpTEST = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/ratbpTEST.txt', delimiter = '\t')
ratbpTRAIN = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/ratbpTRAIN.txt', delimiter = '\t')
salinity = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/salinity.txt', delimiter = '\t')
temperature = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/temperature.txt', delimiter = '\t')
whole = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/TimeSeries/Datasets/whole.txt', delimiter='\t')

# %%
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 10]
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
plt.subplot(221)
plt.plot(Fridge)
plt.subplot(222)
plt.plot(LSF5_10)
plt.subplot(223)
plt.plot(LSF6_10)
plt.subplot(224)
plt.plot(RW1)

plt.show()

# %%
plt.subplot(221)
plt.plot(RW2)
plt.subplot(222)
plt.plot(currency10a)
plt.subplot(223)
plt.plot(currency10b)
plt.subplot(224)
plt.plot(lightCurveA)

plt.show()

# %%
plt.subplot(221)
plt.plot(lightCurveB)
plt.subplot(222)
plt.plot(ratbpTEST)
plt.subplot(223)
plt.plot(ratbpTRAIN)
plt.subplot(224)
plt.plot(salinity)

plt.show()

# %%
plt.plot(temperature)
plt.plot(whole)
plt.show()

# %%
#plt.plot(Fridge)
#plt.plot(LSF5_10)
#plt.plot(LSF6_10) 
plt.plot(RW1)
plt.plot(RW2)
plt.plot(currency10a)
plt.plot(currency10b)
plt.plot(lightCurveA)
plt.plot(lightCurveB) 
plt.plot(ratbpTEST)
plt.plot(ratbpTRAIN)
plt.plot(salinity)
plt.plot(temperature)
#plt.plot(whole)

plt.show()

# %%
plt.plot(Fridge)

# %%
plt.plot(LSF5_10)
plt.plot(LSF6_10)
plt.show()

# %%
plt.plot(RW1)
plt.plot(RW2)

# %%
plt.plot(currency10a)
plt.plot(currency10b)

# %%
plt.plot(lightCurveA)
plt.plot(lightCurveB)

# %%
plt.plot(ratbpTEST)
plt.plot(ratbpTRAIN)

# %%
plt.plot(salinity)
plt.plot(temperature)

# %%
plt.plot(whole)

# %%
plt.subplot(221)
plt.plot(LSF5_10[100:200])
plt.subplot(222)
plt.plot(LSF5_10[200:300])
plt.subplot(223)
plt.plot(LSF5_10[300:400])
plt.subplot(224)
plt.plot(LSF5_10[400:500])
